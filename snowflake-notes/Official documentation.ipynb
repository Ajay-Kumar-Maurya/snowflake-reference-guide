# %% [markdown]
# ### Snowflake Official Documentation
# https://docs.snowflake.com/en/reference
#
# ### Snowpark Documentation :
# https://docs.snowflake.com/en/developer-guide/snowpark/reference/python/latest/snowpark/index

# %% [markdown]
# # Snowflake Documentation References
#
# | Reference | Description | Priority |
# |-----------|-------------|----------|
# | [SQL Data Types Reference](https://docs.snowflake.com/en/sql-reference/data-types) | Information about data types | High |
# | [SQL Command Reference](https://docs.snowflake.com/en/sql-reference/sql-all) | Information about SQL commands | High |
# | [Function and Stored Procedure Reference](https://docs.snowflake.com/en/sql-reference/functions-all) | Snowflake built-in functions and procedures | High |
# | [Class Reference](https://docs.snowflake.com/en/sql-reference/classes) | Snowflake ML & governance classes (ANOMALY_DETECTION, ANOMALY_INSIGHTS, BUDGET, CLASSIFICATION, CLASSIFICATION_PROFILE, CUSTOM_CLASSIFIER, FORECAST, TOP_INSIGHTS) | Very Low (for interviews) |
# | [Scripting Reference](https://docs.snowflake.com/en/developer-guide/snowflake-scripting/index) | Snowflake Scripting keywords (BEGIN, END, DECLARE, IF, FOR, EXCEPTION) | Medium |
# | [General Reference](https://docs.snowflake.com/en/sql-reference/general-reference) | General SQL reference | Low |
# | [API Reference](https://docs.snowflake.com/en/developer-guide) | Snowflake Connector API and Snowpark API integration | Medium |
#
# ## API Reference Details
#
# - **Connector only** → `pip install snowflake-connector-python` (for executing SQL queries)
# - **Snowpark** → `pip install snowflake-snowpark-python` (connector included automatically; for Python DataFrame operations)

# %% [markdown]
# ### Load unstructured data into Snowflake
# https://docs.snowflake.com/en/user-guide/unstructured-intro
