# %% [markdown]
# Binary input and output =>
# Snowflake supports three binary formats or encoding schemes: hex (base-16), base64, and UTF-8. We can store binary data like audio, video, pdf, image, zip, executable into encoded string form.
#
# hex =>
# In this format, each byte is represented by two characters (digits from 0 to 9 and letters from A to F). Hex is the default binary format. We can  convert binary data to hex string.
#
# base64 =>
# The “base64” format encodes binary data as printable ASCII characters (letters, digits, and punctuation marks or mathematical operators).
# Base64-encoded data has the following advantages:
# - Because base64-encoded data is pure ASCII text, it can be stored in systems that support ASCII character data but not BINARY data.
# - Because base64-encoded data doesn’t contain control characters (for example, end-of-transmission characters, tab characters), base64-encoded data can be transmitted and received without risk that control characters could be interpreted as commands rather than as data.
#
# Base64-encoded data has the following disadvantages:
# - Converting data back and forth between binary and printable ASCII representations consumes computation resources.
# - Base64-encoded data requires approximately 1/3 more storage space than the original data.
#
# It is represented by one of the following 64 printable ASCII characters:
# - Uppercase letters (A - Z)
# - Lowercase letters (a - z)
# - Decimal digits (0 - 9)
# - +
# - /
# In addition, the character = is used for padding if the length of the input that isn’t an exact multiple of 3.
#
# UTF-8 =>
# The UTF-8 format refers to the UTF-8 character encoding for Unicode. UTF-8 is used for text-to-binary encoding. UTF-8 can’t be used for binary-to-text encoding. This format is convenient for performing one-to-one conversion between binary and string, for reinterpreting the underlying data as one type or the other rather than actually encoding and decoding.

# %%
%%sql -r dataframe_1
CREATE OR REPLACE TABLE demo_binary_base64 (t TEXT, b BINARY);
